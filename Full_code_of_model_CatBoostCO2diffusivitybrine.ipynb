# %%
import pickle
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
import joblib  # For loading the saved model

# %%
# Load the ET model
model = joblib.load("CATBOOSTCO2DFB.pkl")

# %%
# Load Other data to check the model from an Excel file: This is just an example how to apply the model for other data with unknown IFT value
dataOther = pd.read_excel('DataTest.xlsx')  # Replace 'data.xlsx' with your file path
dataOther
# Out:
#    P (MPa)  T (K)  Viscosity (mPa·s)  Diffusion coefficient (×10^(-9) m2/s)
# 0       14    298               0.89                                   2.23

# %%
# Split the data into features
features = ['P (MPa)','T (K)','Viscosity (mPa·s)','Diffusion coefficient (×10^(-9) m2/s)']
X = dataOther.drop('Diffusion coefficient (×10^(-9) m2/s)', axis=1)

# %%
# Make predictions data
predCO2Diff = model.predict(X)
print(predCO2Diff)
# Out:
# [2.23469542]
